# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
pd.set_option('display.max_colwidth', 500)
import time
import requests
import random

# %%
page = requests.get("https://www.tengizchevroil.com/")
page
# Out:
# <Response [200]>

# %%
page_zakon=requests.get("https://www.zakon.kz/")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# ...

# %%
soup = bs(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="ru"> <head> <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/> <meta content="width=device-width, initial-scale=1" name="viewport"/> <meta charset="utf-8"/> <title>
# 	Домашняя страница
# ...

# %%
soup.find_all(class_='title')
# Out:
# [<div class="title"><a href="https://tengizchevroil.com/about/media/tconews/item/tco-stories/2021/12/15/Rakusha_Kindergarden_Egilik" target="_blank">В Атырау открыл двери новый детский сад на 280 мест</a></div>,
#  <div class="title"><a href="https://tengizchevroil.com/about/media/tconews/item/tco-stories/2022/02/23/tengizchevroil-2021-year-end-results-ru" target="_blank">Тенгизшевройл объявил о результатах 2021 года</a></div>,
#  <div class="title"><a href="https://tengizchevroil.com/about/media/tconews/item/tco-stories/2022/03/01/Ecology_minister_RU" target="_blank">МИНИСТР ЭКОЛОГИИ: Я считаю, совершенству нет предела</a></div>,
#  <div class="title">
#  <a href="https://www.tengizchevroil.com/about/media/tconews/item/tco-stories/2022/09/02/тенгизшевройл-помогает-спасать-каспийского-тюленя">Тенгизшевройл помогает спасать Каспийского тюленя</a>
#  </div>,
#  <div class="title">
# ...

# %%
quotes = [i.text for i in soup.find_all(class_='title')]
quotes
# Out:
# ['В Атырау открыл двери новый детский сад на 280 мест',
#  'Тенгизшевройл объявил о результатах 2021 года',
#  'МИНИСТР ЭКОЛОГИИ: Я считаю, совершенству нет предела',
#  '\nТенгизшевройл помогает спасать Каспийского тюленя\n',
#  '\nТШО – непрерывное совершенствование в целях сокращения выбросов\n',
#  '\nМинистр энергетики РК посетил Тенгизское месторождение\n',
#  '\nГлава КМГ посетил завод третьего поколения на Тенгизе\n',
#  '\nТ. Дуйсенова, С. Шапкенов и К. Лайон подписали Дорожную карту по демобилизации ПБР-ПУУД\n',
#  '\nВниманию пользователей Интернет\n']

# %%
df = pd.DataFrame()

# %%
df['title'] = quotes

# %%
df['source']='Tengizchevroil.com'

# %%
df
# Out:
#                                                                                          title  \
# 0                                          В Атырау открыл двери новый детский сад на 280 мест
# 1                                                Тенгизшевройл объявил о результатах 2021 года
# 2                                         МИНИСТР ЭКОЛОГИИ: Я считаю, совершенству нет предела
# 3                                        \nТенгизшевройл помогает спасать Каспийского тюленя\n
# 4                          \nТШО – непрерывное совершенствование в целях сокращения выбросов\n
# 5                                   \nМинистр энергетики РК посетил Тенгизское месторождение\n
# 6                                    \nГлава КМГ посетил завод третьего поколения на Тенгизе\n
# 7  \nТ. Дуйсенова, С. Шапкенов и К. Лайон подписали Дорожную карту по демобилизации ПБР-ПУУД\n
# 8                                                          \nВниманию пользователей Интернет\n
#
#                source
# ...
